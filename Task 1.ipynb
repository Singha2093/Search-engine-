# %%
import tkinter as tk # Used for creating the GUI components.
from tkinter import ttk #Used for handling and processing tabular data.
import pandas as pd
import requests
from bs4 import BeautifulSoup # Used for web scraping to parse HTML content.
import time
import csv
import webbrowser #Used for opening web links.
from lxml import html #Used for processing HTML and XML.
from collections import defaultdict
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re #Used for making HTTP requests to fetch web pages.
import nltk #Natural Language Toolkit for text processing.

# %%
#Retrieves publication links from a specified base URL using web scraping

# %%
def Link_Retrieval(base_url, num_pages=9):
    Total_PL = []

    for page in range(0, num_pages + 1):
        Link_URL = f"{base_url}?page={page}"
        headers = {
          "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
        response = requests.get(Link_URL, headers=headers)

    # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to fetch {Link_URL}. Status: {response.status_code}")
            continue

        soup = BeautifulSoup(response.content, "html.parser")
        links_on_page = [a["href"] for a in soup.find_all("a", href=True)]
        Total_PL.extend(links_on_page)

        # Polite crawling - add a delay between requests
        time.sleep(2)

    return Total_PL

if __name__ == "__main__":
    base_url = "https://pureportal.coventry.ac.uk/en/organisations/ics-research-centre-for-fluid-and-complex-systems-fcs/publications/"
    Total_PL = Link_Retrieval(base_url, num_pages=9)

    Publication_Link = [link for link in Total_PL if 'publications' in link and 'https://' in link]

    print(f"Total Number of Publication Links: {len(Publication_Link)}")
    for link in Publication_Link:
        print(link)
# Out:
# Total Number of Publication Links: 434
# https://pureportal.coventry.ac.uk/en/publications/alliance-spectral-solver-for-kinetic-plasma-turbulence
# https://pureportal.coventry.ac.uk/en/publications/a-new-synergistic-model-for-simulating-exercise-incorporating-con
# https://pureportal.coventry.ac.uk/en/publications/an-overview-of-dynamical-methods-for-studying-transitions-between
# https://pureportal.coventry.ac.uk/en/publications/antriebstechniken-f%C3%BCr-einen-digitaldurchflussmesser-2
# https://pureportal.coventry.ac.uk/en/publications/an-ultra-precise-fast-fourier-transform-2
# https://pureportal.coventry.ac.uk/en/publications/a-stochastic-model-of-edge-localized-modes-in-magnetically-confin
# https://pureportal.coventry.ac.uk/en/publications/causality-analysis-with-information-geometry-a-comparison
# https://pureportal.coventry.ac.uk/en/publications/coined-quantum-walks-on-the-line-disorder-entanglement-and-locali
# https://pureportal.coventry.ac.uk/en/publications/cooling-channel-free-surface-optimisation-for-additively-manufact
# https://pureportal.coventry.ac.uk/en/publications/critical-dynamical-behavior-of-the-ising-model
# https://pureportal.coventry.ac.uk/en/publications/development-of-a-novel-low-order-model-for-atrial-function-and-a-
# https://pureportal.coventry.ac.uk/en/publications/disorder-effects-on-the-metastability-of-classical-heisenberg-fer
# https://pureportal.coventry.ac.uk/en/publications/effects-of-stochastic-noises-on-limit-cycle-oscillations-and-powe
# https://pureportal.coventry.ac.uk/en/publications/enhanced-measurement-validation-via-ultra-precise-spectral-analys
# https://pureportal.coventry.ac.uk/en/publications/entanglement-gap-in-1d-long-range-quantum-spherical-models
# https://pureportal.coventry.ac.uk/en/publications/entanglement-in-the-quantum-spherical-model-a-review
# https://pureportal.coventry.ac.uk/en/publications/epidemiology-of-chronic-lymphocytic-leukemia-in-sardinia-italy-19
# https://pureportal.coventry.ac.uk/en/publications/finite-size-scaling-of-the-random-field-ising-model-above-the-upp
# https://pureportal.coventry.ac.uk/en/publications/fully-conservative-hydraulic-jumps-and-solibores-in-two-layer-bou
# https://pureportal.coventry.ac.uk/en/publications/geometric-clusters-in-the-overlap-of-the-ising-model
# https://pureportal.coventry.ac.uk/en/publications/heat-transport-enhancement-and-flow-transitions-in-partitioned-th
# https://pureportal.coventry.ac.uk/en/publications/h-mode-dithering-phase-studies-on-st40
# https://pureportal.coventry.ac.uk/en/publications/h-mode-transition-and-pedestal-studies
# https://pureportal.coventry.ac.uk/en/publications/incidence-and-bayesian-mapping-of-myeloid-hematologic-malignancie
# https://pureportal.coventry.ac.uk/en/publications/interplay-of-viscosity-and-wettability-controls-fluid-displacemen
# https://pureportal.coventry.ac.uk/en/publications/intrinsic-disorder-and-conformational-coexistence-in-auxin-corece
# https://pureportal.coventry.ac.uk/en/publications/mathematical-characterization-of-private-and-public-immune-recept
# https://pureportal.coventry.ac.uk/en/publications/mehr-phasen-coriolis-durchflussmessger%C3%A4t-2
# https://pureportal.coventry.ac.uk/en/publications/method-and-system-for-tracking-sinusoidal-wave-parameters-from-a--4
# https://pureportal.coventry.ac.uk/en/publications/multi-phase-flow-metering-system
# https://pureportal.coventry.ac.uk/en/publications/nonlinear-dynamics-of-a-broadband-vortex-induced-vibrationbased-e
# https://pureportal.coventry.ac.uk/en/publications/non-specific-effects-of-the-cinnamate-4-hydroxylase-inhibitor-pip
# https://pureportal.coventry.ac.uk/en/publications/parameter-estimation-of-fractional-order-systems-via-evolutionary
# https://pureportal.coventry.ac.uk/en/publications/realization-of-bullards-disc-dynamo
# https://pureportal.coventry.ac.uk/en/publications/relations-between-entropy-rate-entropy-production-and-information
# https://pureportal.coventry.ac.uk/en/publications/rolling-and-sliding-modes-of-nanodroplet-spreading-molecular-simu
# https://pureportal.coventry.ac.uk/en/publications/selfcontained-twolayer-shallowwater-theory-of-strong-internal-bor
# https://pureportal.coventry.ac.uk/en/publications/statistical-analysis-of-plasma-dynamics-in-gyrokinetic-simulation
# https://pureportal.coventry.ac.uk/en/publications/stochastic-representation-of-the-quantum-quartic-oscillator
# https://pureportal.coventry.ac.uk/en/publications/subcritical-transition-to-turbulence-in-quasi-two-dimensional-she
# https://pureportal.coventry.ac.uk/en/publications/superdiffusion-like-behavior-in-zero-temperature-coarsening-of-th
# https://pureportal.coventry.ac.uk/en/publications/systems-and-methods-for-multiphase-flow-metering-accounting-for-d-7
# https://pureportal.coventry.ac.uk/en/publications/the-effect-of-valve-opening-and-closing-time-on-the-mechano-elect
# https://pureportal.coventry.ac.uk/en/publications/the-relation-between-dissipation-and-memory-in-two-fluid-displace
# https://pureportal.coventry.ac.uk/en/publications/the-structure-and-dynamics-of-networks-with-higher-order-interact
# https://pureportal.coventry.ac.uk/en/publications/time-dependent-probability-density-function-analysis-of-h-mode-tr
# https://pureportal.coventry.ac.uk/en/publications/time-dependent-probability-density-functions-information-geometry
# https://pureportal.coventry.ac.uk/en/publications/transition-from-wall-modes-to-multimodality-in-liquid-gallium-mag
# https://pureportal.coventry.ac.uk/en/publications/two-dimensional-dilute-baxter-wu-model-transition-order-and-unive
# https://pureportal.coventry.ac.uk/en/publications/uncertainty-quantification-of-the-co2-storage-process-in-the-bunt
# https://pureportal.coventry.ac.uk/en/publications/wall-permeability-estimation-in-automotive-particulate-filters
# https://pureportal.coventry.ac.uk/en/publications/a-case-study-of-the-ancientbiotics-collaboration
# https://pureportal.coventry.ac.uk/en/publications/a-community-energy-management-system-for-smart-microgrids
# https://pureportal.coventry.ac.uk/en/publications/additional-data-supporting-the-2022-updates-to-the-iso-5167-stand
# https://pureportal.coventry.ac.uk/en/publications/adenylate-cyclase-activity-of-tir1afb-auxin-receptors-in-plants
# https://pureportal.coventry.ac.uk/en/publications/adjoint-method-for-the-optimisation-of-conformal-cooling-channels
# https://pureportal.coventry.ac.uk/en/publications/an-investigation-of-left-ventricular-valve-disorders-and-the-mech
# https://pureportal.coventry.ac.uk/en/publications/an-ultra-precise-fast-fourier-transform
# https://pureportal.coventry.ac.uk/en/publications/applying-a-non-invasive-multi-spectral-sensing-technique-to-two-p
# https://pureportal.coventry.ac.uk/en/publications/are-the-available-data-from-laboratory-spray-burners-suitable-for
# https://pureportal.coventry.ac.uk/en/publications/a-statistical-analysis-approach-of-plasma-dynamics-in-gyrokinetic
# https://pureportal.coventry.ac.uk/en/publications/author-correction-time-trend-and-bayesian-mapping-of-multiple-mye
# https://pureportal.coventry.ac.uk/en/publications/big-fish-and-small-ponds-why-the-departmental-h-index-should-not-
# https://pureportal.coventry.ac.uk/en/publications/big-fish-and-small-ponds-why-the-departmental-h-index-should-not--2
# https://pureportal.coventry.ac.uk/en/publications/comment-on-linear-stability-of-a-rotating-channel-flow-subjected-
# https://pureportal.coventry.ac.uk/en/publications/corrections-to-scaling-in-geometrical-clusters-of-the-2d-ising-mo
# https://pureportal.coventry.ac.uk/en/publications/differential-radial-basis-function-network-for-sequence-modelling
# https://pureportal.coventry.ac.uk/en/publications/diii-d-research-advancing-the-physics-basis-for-optimizing-the-to
# https://pureportal.coventry.ac.uk/en/publications/efficient-algorithms-for-computing-ground-states-of-the-2d-random
# https://pureportal.coventry.ac.uk/en/publications/entanglement-dynamics-of-a-hard-core-quantum-gas-during-a-joule-e
# https://pureportal.coventry.ac.uk/en/publications/evolution-and-maintenance-of-phenotypic-plasticity
# https://pureportal.coventry.ac.uk/en/publications/exact-time-dependent-solutions-and-information-geometry-of-a-rock
# https://pureportal.coventry.ac.uk/en/publications/experimental-pub-crawl-from-rayleighb%C3%A9nard-to-magnetostrophic-con
# https://pureportal.coventry.ac.uk/en/publications/fastest-with-no-overshoot-velocity-control-design-of-a-two-differ
# https://pureportal.coventry.ac.uk/en/publications/fisher-information-approach-to-understand-the-gompertz-model
# https://pureportal.coventry.ac.uk/en/publications/flamelet-generated-manifold-simulation-of-highly-swirling-spray-c
# https://pureportal.coventry.ac.uk/en/publications/flow-measurement-challenges-for-carbon-capture-utilisation-and-st
# https://pureportal.coventry.ac.uk/en/publications/four-dimensional-equations-for-the-study-of-electromagnetic-plasm
# https://pureportal.coventry.ac.uk/en/publications/further-remarks-on-irrational-systems-and-their-applications
# https://pureportal.coventry.ac.uk/en/publications/gaussian-process-models-for-well-placement-optimisation
# https://pureportal.coventry.ac.uk/en/publications/improved-prediction-of-clay-soil-expansion-using-machine-learning
# https://pureportal.coventry.ac.uk/en/publications/incidence-of-non-hodgkins-lymphoma-among-adults-in-sardinia-italy
# https://pureportal.coventry.ac.uk/en/publications/information-geometry-control-under-the-laplace-assumption
# https://pureportal.coventry.ac.uk/en/publications/information-length-in-dynamical-systems
# https://pureportal.coventry.ac.uk/en/publications/information-length-quantification-and-forecasting-of-power-system
# https://pureportal.coventry.ac.uk/en/publications/jump-rope-vortex-flow-in-liquid-metal-rayleighb%C3%A9nard-convection-i
# https://pureportal.coventry.ac.uk/en/publications/lock-exchange-problem-for-boussinesq-fluids-revisited-exact-shall
# https://pureportal.coventry.ac.uk/en/publications/magnetic-damping-of-jet-flows-in-quasi-two-dimensional-rayleigh-b
# https://pureportal.coventry.ac.uk/en/publications/mean-field-nature-of-synchronization-stability-in-networks-with-m
# https://pureportal.coventry.ac.uk/en/publications/method-and-system-for-ultra-narrowband-filtering-with-signal-proc-4
# https://pureportal.coventry.ac.uk/en/publications/minimum-information-variability-in-linear-langevin-systems-via-mo
# https://pureportal.coventry.ac.uk/en/publications/monte-carlo-simulation-of-stochastic-differential-equation-to-stu
# https://pureportal.coventry.ac.uk/en/publications/multicanonical-simulations-of-the-2d-spin-1-baxter-wu-model-in-a-
# https://pureportal.coventry.ac.uk/en/publications/network-analysis-of-the-kyiv-bylyny-cycle-east-slavic-epic-narrat
# https://pureportal.coventry.ac.uk/en/publications/n-groups-formation-of-differential-robots
# https://pureportal.coventry.ac.uk/en/publications/non-equilibrium-statistical-properties-path-dependent-information
# https://pureportal.coventry.ac.uk/en/publications/onset-of-convective-instability-in-an-inclined-porous-medium
# https://pureportal.coventry.ac.uk/en/publications/on-the-development-and-validation-of-the-double-integral-method-f
# https://pureportal.coventry.ac.uk/en/publications/operation-and-verification-of-a-dual-mode-coriolis-meter-using-pr
# https://pureportal.coventry.ac.uk/en/publications/phase-transitions-above-the-upper-critical-dimension
# https://pureportal.coventry.ac.uk/en/publications/poromechanical-analysis-of-oil-well-cements-in-cosub2sub-rich-env
# https://pureportal.coventry.ac.uk/en/publications/power-systems-coherency-representation-and-identification-as-part
# https://pureportal.coventry.ac.uk/en/publications/roadmap-on-signal-processing-for-next-generation-measurement-syst
# https://pureportal.coventry.ac.uk/en/publications/schottkys-forgotten-step-to-the-ising-model
# https://pureportal.coventry.ac.uk/en/publications/spherical-solidification-an-application-of-the-integral-methods
# https://pureportal.coventry.ac.uk/en/publications/the-elbert-range-of-magnetostrophic-convection-i-linear-theory
# https://pureportal.coventry.ac.uk/en/publications/the-enigmatic-fraoch-and-his-eponymous-tale-network-analysis-of-a
# https://pureportal.coventry.ac.uk/en/publications/the-impact-of-heterogeneous-mixed-siliciclasticcarbonate-systems-
# https://pureportal.coventry.ac.uk/en/publications/thermoelectric-precession-in-turbulent-magnetoconvection
# https://pureportal.coventry.ac.uk/en/publications/time-trend-and-bayesian-mapping-of-multiple-myeloma-incidence-in-
# https://pureportal.coventry.ac.uk/en/publications/transient-behavior-of-damaging-spreading-in-the-two-dimensional-b
# https://pureportal.coventry.ac.uk/en/publications/universality-in-the-two-dimensional-dilute-baxter-wu-model
# https://pureportal.coventry.ac.uk/en/publications/use-of-biochar-to-manage-soil-salts-and-water-effects-and-mechani
# https://pureportal.coventry.ac.uk/en/publications/using-multi-objective-optimisation-with-adm1-and-measured-data-to
# https://pureportal.coventry.ac.uk/en/publications/weighted-averages-in-population-annealing-analysis-and-general-fr
# https://pureportal.coventry.ac.uk/en/publications/xxxii-iupap-conference-on-computational-physics
# https://pureportal.coventry.ac.uk/en/publications/a-fractional-order-model-of-the-cardiac-function
# https://pureportal.coventry.ac.uk/en/publications/a-methodology-for-reactive-transport-modelling-and-geomechanical-
# https://pureportal.coventry.ac.uk/en/publications/analysis-of-derating-and-anti-icing-strategies-for-wind-turbines-
# https://pureportal.coventry.ac.uk/en/publications/analysis-of-standalone-solar-streetlights-for-improved-energy-acc
# https://pureportal.coventry.ac.uk/en/publications/assessment-of-energy-potential-of-date-palm-residues-in-khairpur-
# https://pureportal.coventry.ac.uk/en/publications/a-study-on-the-impact-of-storage-boundary-and-caprock-morphology-
# https://pureportal.coventry.ac.uk/en/publications/a-transposon-surveillance-mechanism-that-safeguards-plant-male-fe
# https://pureportal.coventry.ac.uk/en/publications/author-correction-the-origin-of-hysteresis-and-memory-of-two-phas
# https://pureportal.coventry.ac.uk/en/publications/building-billion-tap-filters-prism-signal-processing
# https://pureportal.coventry.ac.uk/en/publications/causal-information-rate
# https://pureportal.coventry.ac.uk/en/publications/conformal-cooling-of-aluminium-flat-fins-using-a-3d-printed-water
# https://pureportal.coventry.ac.uk/en/publications/deformation-bands-in-high-porosity-sandstones-do-they-help-or-hin
# https://pureportal.coventry.ac.uk/en/publications/direct-numerical-simulation-of-quasi-two-dimensional-mhd-turbulen
# https://pureportal.coventry.ac.uk/en/publications/dna-thermal-denaturation-by-polymer-field-theory-approach-effects
# https://pureportal.coventry.ac.uk/en/publications/extracting-partition-function-zeros-from-fukui-todo-simulations
# https://pureportal.coventry.ac.uk/en/publications/fractality-of-metal-pad-instability-threshold-in-rectangular-cell
# https://pureportal.coventry.ac.uk/en/publications/fractionalorder-controllers-for-irrational-systems
# https://pureportal.coventry.ac.uk/en/publications/generalized-ising-model-on-a-scale-free-network-an-interplay-of-p
# https://pureportal.coventry.ac.uk/en/publications/grid-frequency-estimation-based-on-extended-kalman-filter-in-conn
# https://pureportal.coventry.ac.uk/en/publications/high-speed-density-measurement-for-lng-and-other-cryogenic-fluids
# https://pureportal.coventry.ac.uk/en/publications/horizontal-shear-instabilities-in-rotating-stellar-radiation-zone-2
# https://pureportal.coventry.ac.uk/en/publications/impact-of-the-number-of-computational-parcels-on-the-prediction-o
# https://pureportal.coventry.ac.uk/en/publications/information-geometric-theory-in-the-prediction-of-abrupt-changes-
# https://pureportal.coventry.ac.uk/en/publications/information-geometry-fluctuations-non-equilibrium-thermodynamics-
# https://pureportal.coventry.ac.uk/en/publications/information-geometry-and-non-equilibrium-thermodynamic-relations-
# https://pureportal.coventry.ac.uk/en/publications/metastable-behavior-of-the-spin-s-ising-and-blume-capel-ferromagn
# https://pureportal.coventry.ac.uk/en/publications/modelling-the-cardiac-response-to-a-mechanical-stimulation-using-
# https://pureportal.coventry.ac.uk/en/publications/model-reduction-and-control-design-of-a-multi-agent-line-formatio
# https://pureportal.coventry.ac.uk/en/publications/monte-carlo-study-of-the-two-dimensional-kinetic-blume-capel-mode
# https://pureportal.coventry.ac.uk/en/publications/multiphase-flow-metering
# https://pureportal.coventry.ac.uk/en/publications/non-equilibrium-dynamics-of-the-open-quantum-on-model-with-non-ma
# https://pureportal.coventry.ac.uk/en/publications/on-line-coherency-analysis-based-on-sliding-window-koopman-mode-d
# https://pureportal.coventry.ac.uk/en/publications/onset-of-transient-convection-in-a-porous-medium-with-an-embedded-2
# https://pureportal.coventry.ac.uk/en/publications/onset-of-transient-convection-in-a-porous-medium-with-an-embedded
# https://pureportal.coventry.ac.uk/en/publications/optimising-feedstock-flowrate-to-improve-the-performance-of-an-ex
# https://pureportal.coventry.ac.uk/en/publications/optimization-of-conformal-cooling-channels-for-rapid-prototyped-m
# https://pureportal.coventry.ac.uk/en/publications/oscillatory-thermal-inertial-flows-in-liquid-metal-rotating-conve
# https://pureportal.coventry.ac.uk/en/publications/parametric-study-on-the-integrity-of-wellbores-in-co2-storage-sit
# https://pureportal.coventry.ac.uk/en/publications/relationship-of-soil-moisture-characteristic-curve-and-mechanical
# https://pureportal.coventry.ac.uk/en/publications/reservoir-characterization-and-volumetric-estimation-of-reservoir
# https://pureportal.coventry.ac.uk/en/publications/simplified-cfd-model-for-assessing-the-cooling-channel-design-in-
# https://pureportal.coventry.ac.uk/en/publications/solute-driven-transient-convection-in-layered-porous-media
# https://pureportal.coventry.ac.uk/en/publications/spectral-analysis-techniques-using-prism-signal-processing
# https://pureportal.coventry.ac.uk/en/publications/stability-of-pulsatile-quasi-two-dimensional-duct-flows-under-a-t
# https://pureportal.coventry.ac.uk/en/publications/stability-of-the-flow-due-to-a-linear-stretching-sheet
# https://pureportal.coventry.ac.uk/en/publications/sub-grid-scale-effects-in-magnetised-plasma-turbulence
# https://pureportal.coventry.ac.uk/en/publications/support-vector-machine-modelling-applied-to-benchmark-data-set-fo
# https://pureportal.coventry.ac.uk/en/publications/systematic-comparison-between-the-generalized-lorenz-equations-an
# https://pureportal.coventry.ac.uk/en/publications/the-challenges-of-community-based-solar-energy-interventions-less
# https://pureportal.coventry.ac.uk/en/publications/the-complex-interplay-between-tidal-inertial-waves-and-zonal-flow
# https://pureportal.coventry.ac.uk/en/publications/the-onset-of-instabilities-and-finite-amplitude-waves-in-a-model-
# https://pureportal.coventry.ac.uk/en/publications/tornado-like-vortices-in-the-quasi-cyclostrophic-regime-of-coriol
# https://pureportal.coventry.ac.uk/en/publications/unravelling-the-large-scale-circulation-modes-in-turbulent-raylei
# https://pureportal.coventry.ac.uk/en/publications/wormholing-in-anisotropic-media-pore-scale-effect-on-large-scale-
# https://pureportal.coventry.ac.uk/en/publications/alternative-operational-strategies-for-wind-turbines-in-cold-clim
# https://pureportal.coventry.ac.uk/en/publications/analysing-the-role-of-caprock-morphology-on-history-matching-of-s
# https://pureportal.coventry.ac.uk/en/publications/a-new-non-linear-rans-model-with-enhanced-near-wall-treatment-of-
# https://pureportal.coventry.ac.uk/en/publications/boundary-zonal-flow-in-rotating-turbulent-rayleigh-b%C3%A9nard-convect
# https://pureportal.coventry.ac.uk/en/publications/can-deformation-bands-act-as-mini-structural-traps-for-secure-geo
# https://pureportal.coventry.ac.uk/en/publications/character-networks-of-the-%C3%ADslendinga-s%C3%B6gur-and-%C3%BE%C3%A6ttir
# https://pureportal.coventry.ac.uk/en/publications/computational-hardness-of-spin-glass-problems-with-tile-planted-s
# https://pureportal.coventry.ac.uk/en/publications/computing-with-coderunner-at-coventry-university-automated-summat
# https://pureportal.coventry.ac.uk/en/publications/connections-between-non-rotating-slowly-rotating-and-rapidly-rota
# https://pureportal.coventry.ac.uk/en/publications/coriolis-flow-meter
# https://pureportal.coventry.ac.uk/en/publications/coriolis-frequency-tracking-5
# https://pureportal.coventry.ac.uk/en/publications/coriolis-meter-density-errors-induced-by-ambient-air-and-fluid-te
# https://pureportal.coventry.ac.uk/en/publications/cylindrical-algebraic-decomposition-with-equational-constraints
# https://pureportal.coventry.ac.uk/en/publications/data-mining-a-medieval-medical-text-reveals-patterns-in-ingredien
# https://pureportal.coventry.ac.uk/en/publications/development-of-a-wireless-pressure-transmitter-with-diagnostics
# https://pureportal.coventry.ac.uk/en/publications/electromagnetic-technique-for-hydrocarbon-and-sand-transport-moni
# https://pureportal.coventry.ac.uk/en/publications/elucidating-plasma-dynamics-in-hasegawa-wakatani-turbulence-by-in
# https://pureportal.coventry.ac.uk/en/publications/enhancing-co2-solubility-in-the-aquifer-with-the-use-of-a-downhol
# https://pureportal.coventry.ac.uk/en/publications/first-year-computer-science-projects-at-coventry-university-activ
# https://pureportal.coventry.ac.uk/en/publications/haemolymphatic-cancer-among-children-in-sardinia-italy-19742003-i
# https://pureportal.coventry.ac.uk/en/publications/identifying-the-parametric-occurrence-of-multiple-steady-states-f
# https://pureportal.coventry.ac.uk/en/publications/impact-of-matrix-deformations-on-drying-of-granular-materials
# https://pureportal.coventry.ac.uk/en/publications/impact-of-reservoir-permeability-permeability-anisotropy-and-desi
# https://pureportal.coventry.ac.uk/en/publications/improved-cross-validation-for-classifiers-that-make-algorithmic-c
# https://pureportal.coventry.ac.uk/en/publications/influence-of-long-term-thermal-history-on-thermal-comfort-and-pre
# https://pureportal.coventry.ac.uk/en/publications/information-length-analysis-of-linear-autonomous-stochastic-proce
# https://pureportal.coventry.ac.uk/en/publications/information-length-as-a-useful-index-to-understand-variability-in
# https://pureportal.coventry.ac.uk/en/publications/investigating-the-impact-of-temperature-on-relative-permeability-
# https://pureportal.coventry.ac.uk/en/publications/ising-model-with-variable-spinagent-strengths
# https://pureportal.coventry.ac.uk/en/publications/ising-universality-in-the-two-dimensional-blume-capel-model-with-
# https://pureportal.coventry.ac.uk/en/publications/keynote-an-introduction-to-prism-signal-processing
# https://pureportal.coventry.ac.uk/en/publications/low-and-high-drag-intermittencies-in-turbulent-channel-flows
# https://pureportal.coventry.ac.uk/en/publications/magnetic-and-thermodynamic-properties-of-the-octanuclear-nickel-p
# https://pureportal.coventry.ac.uk/en/publications/massively-parallel-simulations-for-disordered-systems
# https://pureportal.coventry.ac.uk/en/publications/mean-flow-anisotropy-without-waves-in-rotating-turbulence
# https://pureportal.coventry.ac.uk/en/publications/mechano-electric-effect-and-a-heart-assist-device-in-the-synergis
# https://pureportal.coventry.ac.uk/en/publications/mitigating-allocation-and-hydrocarbon-accounting-uncertainty-usin
# https://pureportal.coventry.ac.uk/en/publications/mixed-baroclinic-convection-in-a-cavity
# https://pureportal.coventry.ac.uk/en/publications/mixing-demixing-transition-in-polymer-grafted-spherical-nanoparti
# https://pureportal.coventry.ac.uk/en/publications/modelling-fluid-loss-faults-in-an-industrial-pressure-sensor
# https://pureportal.coventry.ac.uk/en/publications/modelling-fluid-loss-faults-in-piezoresistive-pressure-sensors
# https://pureportal.coventry.ac.uk/en/publications/multi-channel-modelling-approach-for-particulate-filters
# https://pureportal.coventry.ac.uk/en/publications/multimodal-analysis-of-gas-oil-intermittent-structures-in-co-curr
# https://pureportal.coventry.ac.uk/en/publications/narrative-structure-of-a-song-of-ice-and-fire-creates-a-fictional
# https://pureportal.coventry.ac.uk/en/publications/non-newtonian-channel-flowexact-solutions
# https://pureportal.coventry.ac.uk/en/publications/onset-of-convective-instability-in-a-porous-medium-with-a-low-per
# https://pureportal.coventry.ac.uk/en/publications/on-the-highly-swirling-flow-through-a-confined-bluff-body
# https://pureportal.coventry.ac.uk/en/publications/on-the-life-and-habits-of-gas-core-slugs-characterisation-of-an-i
# https://pureportal.coventry.ac.uk/en/publications/on-the-stability-of-a-heated-rotating-disk-boundary-layer-in-a-te
# https://pureportal.coventry.ac.uk/en/publications/piv-mapping-of-pressure-and-velocity-fields-in-the-plane-magnetoh
# https://pureportal.coventry.ac.uk/en/publications/plenary-measurement-for-the-digital-industries-challenges-and-opp
# https://pureportal.coventry.ac.uk/en/publications/quantitative-evaluation-of-the-joint-effect-of-uncertain-paramete
# https://pureportal.coventry.ac.uk/en/publications/reactive-flow-and-homogenization-in-anisotropic-media
# https://pureportal.coventry.ac.uk/en/publications/simultaneous-eulerian-lagrangian-velocity-measurements-of-particu
# https://pureportal.coventry.ac.uk/en/publications/subcritical-route-to-turbulence-via-the-orr-mechanism-in-a-quasi-
# https://pureportal.coventry.ac.uk/en/publications/symbolic-computation-and-satisfiability-checking
# https://pureportal.coventry.ac.uk/en/publications/the-influence-of-temperature-on-wettability-alteration-during-co-
# https://pureportal.coventry.ac.uk/en/publications/the-origin-of-hysteresis-and-memory-of-two-phase-flow-in-disorder
# https://pureportal.coventry.ac.uk/en/publications/time-dependent-probability-density-functions-and-information-diag
# https://pureportal.coventry.ac.uk/en/publications/time-dependent-probability-density-functions-and-information-geom-2
# https://pureportal.coventry.ac.uk/en/publications/transition-between-advection-and-inertial-wave-propagation-in-rot
# https://pureportal.coventry.ac.uk/en/publications/two-cultures-them-and-us-in-the-academic-world
# https://pureportal.coventry.ac.uk/en/publications/a-box-regularized-particle-filter-for-state-estimation-with-sever
# https://pureportal.coventry.ac.uk/en/publications/accelerating-co2-solubility-in-brine-with-low-temperature-injecti
# https://pureportal.coventry.ac.uk/en/publications/accelerating-molecular-dynamics-simulations-with-population-annea
# https://pureportal.coventry.ac.uk/en/publications/a-compositional-thermal-multiphase-wellbore-model-for-use-in-non-
# https://pureportal.coventry.ac.uk/en/publications/a-comprehensive-sensitivity-analysis-on-co2-plume-migration-and-t
# https://pureportal.coventry.ac.uk/en/publications/adjoint-optimization-of-conformal-cooling-channels-for-rapid-prot
# https://pureportal.coventry.ac.uk/en/publications/a-history-matching-approach-to-estimate-caprock-morphology-parame
# https://pureportal.coventry.ac.uk/en/publications/algorithmically-generating-new-algebraic-features-of-polynomial-s
# https://pureportal.coventry.ac.uk/en/publications/alternative-transient-eddy-current-flowmetering-methods-for-liqui
# https://pureportal.coventry.ac.uk/en/publications/a-new-approach-for-determining-optimum-location-of-injection-well
# https://pureportal.coventry.ac.uk/en/publications/a-new-take-on-porous-medium-approach-for-modelling-monoliths-and-
# https://pureportal.coventry.ac.uk/en/publications/an-examination-of-comfort-and-sensation-for-manual-and-automatic-
# https://pureportal.coventry.ac.uk/en/publications/an-instability-mechanism-for-particulate-pipe-flow
# https://pureportal.coventry.ac.uk/en/publications/assessing-the-impact-of-relative-permeability-and-capillary-heter
# https://pureportal.coventry.ac.uk/en/publications/a-study-on-the-chemo-mechanical-alteration-of-cement-in-co2-stora
# https://pureportal.coventry.ac.uk/en/publications/benchmarking-of-vertically-integrated-models-for-the-study-of-the
# https://pureportal.coventry.ac.uk/en/publications/cfd-simulation-and-testing-of-a-turbocharger-compressor-for-vario
# https://pureportal.coventry.ac.uk/en/publications/characterisation-of-the-effects-of-sensor-geometry-on-the-perform
# https://pureportal.coventry.ac.uk/en/publications/characterising-the-role-of-parametric-functions-in-the-van-genuch
# https://pureportal.coventry.ac.uk/en/publications/co2-storage-in-the-carbonate-siliciclastic-system
# https://pureportal.coventry.ac.uk/en/publications/comparing-machine-learning-models-to-choose-the-variable-ordering
# https://pureportal.coventry.ac.uk/en/publications/comprehensive-comparison-of-pore-scale-models-for-multiphase-flow
# https://pureportal.coventry.ac.uk/en/publications/conformal-cooling-of-aluminium-flat-fins-using-a-3-d-printed-wate
# https://pureportal.coventry.ac.uk/en/publications/coriolis-density-error-targeting-ambient-temperature-fluctuation-
# https://pureportal.coventry.ac.uk/en/publications/cps-data-streams-analytics-based-on-machine-learning-for-cloud-an
# https://pureportal.coventry.ac.uk/en/publications/dependence-on-temperature-and-salinity-gradients-and-the-injectio
# https://pureportal.coventry.ac.uk/en/publications/durability-of-oilwell-cement-in-co2-rich-environments
# https://pureportal.coventry.ac.uk/en/publications/effect-of-numerical-error-due-to-heterogeneous-permeability-on-th
# https://pureportal.coventry.ac.uk/en/publications/effect-of-sedimentary-heterogeneities-in-the-sealing-formation-on
# https://pureportal.coventry.ac.uk/en/publications/effect-of-split-injection-on-fuel-mixing-and-cylinder-flow-charac
# https://pureportal.coventry.ac.uk/en/publications/effect-of-systematic-and-random-flow-measurement-errors-on-histor-2
# https://pureportal.coventry.ac.uk/en/publications/effects-of-mirror-geometry-on-the-optical-efficiency-of-a-linear-
# https://pureportal.coventry.ac.uk/en/publications/estimating-the-density-of-states-of-frustrated-spin-systems
# https://pureportal.coventry.ac.uk/en/publications/evaluation-of-enhancing-co2-sequestration-by-post-brine-injection
# https://pureportal.coventry.ac.uk/en/publications/evidence-for-supersymmetry-in-the-random-field-ising-model-at-d-5
# https://pureportal.coventry.ac.uk/en/publications/fifth-international-conference-on-sustainable-construction-materi-6
# https://pureportal.coventry.ac.uk/en/publications/fifth-international-conference-on-sustainable-construction-materi
# https://pureportal.coventry.ac.uk/en/publications/fifth-international-conference-on-sustainable-construction-materi-2
# https://pureportal.coventry.ac.uk/en/publications/fractional-pd%CE%BC-controllers-for-irrational-systems
# https://pureportal.coventry.ac.uk/en/publications/heartbeat-design-for-energy-aware-iot-are-your-sensors-alive
# https://pureportal.coventry.ac.uk/en/publications/high-precision-studies-of-domain-wall-properties-in-the-2d-gaussi
# https://pureportal.coventry.ac.uk/en/publications/how-can-statistical-data-analysis-reduce-the-cost-of-energy-produ
# https://pureportal.coventry.ac.uk/en/publications/if-cheap-easy-oil-is-over-what-now
# https://pureportal.coventry.ac.uk/en/publications/immiscible-fluid-displacement-in-porous-media-with-spatially-corr
# https://pureportal.coventry.ac.uk/en/publications/information-length-as-a-new-diagnostic-of-stochastic-resonance
# https://pureportal.coventry.ac.uk/en/publications/investigating-the-impact-of-caprock-morphology-on-co2-plume-migra
# https://pureportal.coventry.ac.uk/en/publications/matched-asymptotic-analysis-of-self-similar-blow-up-profiles-of-t
# https://pureportal.coventry.ac.uk/en/publications/modeling-industry-40-based-fog-computing-environments-for-applica
# https://pureportal.coventry.ac.uk/en/publications/modelling-pressure-losses-in-gasoline-particulate-filters-in-high
# https://pureportal.coventry.ac.uk/en/publications/monte-carlo-study-of-the-interfacial-adsorption-of-the-blume-cape
# https://pureportal.coventry.ac.uk/en/publications/multiple-regression-based-prediction-correlations-for-enhanced-se
# https://pureportal.coventry.ac.uk/en/publications/numerical-analysis-of-flat-corners-cooling-of-3d-printed-high-pre
# https://pureportal.coventry.ac.uk/en/publications/on-the-critical-exponent-%CE%B1-of-the-5d-random-field-ising-model
# https://pureportal.coventry.ac.uk/en/publications/plit-an-alignment-free-computational-tool-for-identification-of-l
# https://pureportal.coventry.ac.uk/en/publications/population-annealing-molecular-dynamics-with-adaptive-temperature
# https://pureportal.coventry.ac.uk/en/publications/prediction-of-the-lifespan-of-cement-at-a-specific-depth-based-on
# https://pureportal.coventry.ac.uk/en/publications/remote-sensing-technologies-and-energy-applications-in-refugee-ca
# https://pureportal.coventry.ac.uk/en/publications/synergistic-model-of-cardiac-function-with-a-heart-assist-device
# https://pureportal.coventry.ac.uk/en/publications/the-impact-of-regular-well-testing-on-the-accuracy-of-allocation-
# https://pureportal.coventry.ac.uk/en/publications/the-importance-of-lithofacies-control-on-fluid-migration-in-heter
# https://pureportal.coventry.ac.uk/en/publications/the-instability-of-non-newtonian-boundary-layer-flows-over-rough-
# https://pureportal.coventry.ac.uk/en/publications/the-role-of-flow-measurement-in-hydrocarbon-recovery-forecasting-
# https://pureportal.coventry.ac.uk/en/publications/the-specific-heat-and-magnetic-properties-of-two-species-of-spin-
# https://pureportal.coventry.ac.uk/en/publications/transition-to-chaos-in-an-acoustically-driven-cavity-flow
# https://pureportal.coventry.ac.uk/en/publications/turbulence-in-a-stably-stratified-fluid-onset-of-global-anisotrop
# https://pureportal.coventry.ac.uk/en/publications/turbulent-flow-pressure-losses-in-gasoline-particulate-filters
# https://pureportal.coventry.ac.uk/en/publications/universality-and-exact-finite-size-corrections-for-spanning-trees
# https://pureportal.coventry.ac.uk/en/publications/use-of-the-complex-zeros-of-the-partition-function-to-investigate
# https://pureportal.coventry.ac.uk/en/publications/water-cut-determination-in-co-current-liquid-liquid-flow-using-el
# https://pureportal.coventry.ac.uk/en/publications/a-fog-computing-approach-for-localization-in-wsn
# https://pureportal.coventry.ac.uk/en/publications/a-review-of-oil-well-cement-alteration-in-co2-rich-environments
# https://pureportal.coventry.ac.uk/en/publications/a-short-review-on-oil-well-cement-alteration-in-geological-co2-st
# https://pureportal.coventry.ac.uk/en/publications/box-particle-control-for-aerospace-vehicles-guidance-under-failur
# https://pureportal.coventry.ac.uk/en/publications/complex-network-approach-for-visualizing-and-quantifying-the-evol
# https://pureportal.coventry.ac.uk/en/publications/data-mining-in-scientometrics-usage-analysis-for-academic-publica
# https://pureportal.coventry.ac.uk/en/publications/detecting-and-correcting-for-coriolis-meter-calculated-fluid-dens
# https://pureportal.coventry.ac.uk/en/publications/drying-and-percolation-in-spatially-correlated-porous-media
# https://pureportal.coventry.ac.uk/en/publications/fog-centric-localization-for-ambient-assisted-living
# https://pureportal.coventry.ac.uk/en/publications/fractional-pd%CE%BC-controller-for-transparent-bilateral-control-schem
# https://pureportal.coventry.ac.uk/en/publications/hysteresis-in-multiphase-flow-in-fractured-and-porous-media
# https://pureportal.coventry.ac.uk/en/publications/investigating-the-impact-of-relative-permeability-curves-on-cold-
# https://pureportal.coventry.ac.uk/en/publications/numerical-study-of-natural-convection-in-square-tilted-solar-cavi
# https://pureportal.coventry.ac.uk/en/publications/plenary-prism-checking-the-correctness-of-measurements-for-the-in
# https://pureportal.coventry.ac.uk/en/publications/predictive-modelling-of-co2-storage-in-aquifers-integrating-the-e
# https://pureportal.coventry.ac.uk/en/publications/profiling-and-trending-of-coriolis-meter-secondary-process-value-
# https://pureportal.coventry.ac.uk/en/publications/pv-based-solutions-for-energy-access-in-refugee-camps
# https://pureportal.coventry.ac.uk/en/publications/simple-advecting-structures-and-the-edge-of-chaos-in-subcritical-
# https://pureportal.coventry.ac.uk/en/publications/the-impact-of-gradational-contact-at-the-reservoir-seal-interface
# https://pureportal.coventry.ac.uk/en/publications/the-prediction-of-cement-alteration-in-co2-rich-environments-and-
# https://pureportal.coventry.ac.uk/en/publications/using-single-sensor-hot-wire-anemometry-for-velocity-measurements
# https://pureportal.coventry.ac.uk/en/publications/an-introduction-to-prism-signal-processing
# https://pureportal.coventry.ac.uk/en/publications/an-introduction-to-prism-signal-processing-applied-to-measurement
# https://pureportal.coventry.ac.uk/en/publications/a-percolationbased-approach-to-scaling-infiltration-and-evapotran
# https://pureportal.coventry.ac.uk/en/publications/cooperative-in-network-computation-in-energy-harvesting-device-cl
# https://pureportal.coventry.ac.uk/en/publications/effects-of-flow-measurement-errors-on-oil-and-gas-production-fore
# https://pureportal.coventry.ac.uk/en/publications/fog-enabled-wsn-system-for-animal-behavior-analysis-in-precision-
# https://pureportal.coventry.ac.uk/en/publications/graph-analysis-of-fog-computing-systems-for-industry-40
# https://pureportal.coventry.ac.uk/en/publications/linear-classifier-design-for-heteroscedastic-lda-under-class-imba
# https://pureportal.coventry.ac.uk/en/publications/magnetic-field-dynamos-and-magnetically-triggered-flow-instabilit
# https://pureportal.coventry.ac.uk/en/publications/maths-meets-myths-quantitative-approaches-to-ancient-narratives
# https://pureportal.coventry.ac.uk/en/publications/monitoring-and-modeling-infiltrationrecharge-dynamics-of-managed-
# https://pureportal.coventry.ac.uk/en/publications/platform-as-a-service-gateway-for-the-fog-of-things-2
# https://pureportal.coventry.ac.uk/en/publications/plenary-measurement-validation-for-the-internet-of-things
# https://pureportal.coventry.ac.uk/en/publications/prism-signal-processing-for-diesel-engine-fuel-injection-monitori
# https://pureportal.coventry.ac.uk/en/publications/prism-signal-processing-for-dual-mode-coriolis-flow-metering
# https://pureportal.coventry.ac.uk/en/publications/shaftless-multi-blade-wind-turbine
# https://pureportal.coventry.ac.uk/en/publications/the-effect-of-swirl-on-the-flow-uniformity-in-automotive-exhaust-
# https://pureportal.coventry.ac.uk/en/publications/using-edge-analytics-to-improve-data-collection-in-precision-dair
# https://pureportal.coventry.ac.uk/en/publications/an-engineering-solution-for-co2-injection-in-saline-aquifers-2
# https://pureportal.coventry.ac.uk/en/publications/collaborative-edge-mining-for-predicting-heat-stress-in-dairy-cat
# https://pureportal.coventry.ac.uk/en/publications/determining-concentrations-of-components-of-a-mixture-7
# https://pureportal.coventry.ac.uk/en/publications/drying-in-microfluidic-cells
# https://pureportal.coventry.ac.uk/en/publications/effects-of-pore-scale-disorder-on-fluid-displacement-in-partially
# https://pureportal.coventry.ac.uk/en/publications/impact-of-heterogeneity-and-matrix-deformations-on-drying-of-gran
# https://pureportal.coventry.ac.uk/en/publications/investigation-of-co2-storage-in-a-saline-formation-with-an-angula-2
# https://pureportal.coventry.ac.uk/en/publications/investigation-of-the-effects-of-unconformity-surface-on-geologica
# https://pureportal.coventry.ac.uk/en/publications/k-means-clustering-using-tabu-search-with-quantized-means
# https://pureportal.coventry.ac.uk/en/publications/multiphase-flow-meter
# https://pureportal.coventry.ac.uk/en/publications/otomatik-kaynak-diki%C5%9F-izi-takip-y%C3%B6ntemi-ve-araci
# https://pureportal.coventry.ac.uk/en/publications/simulations-of-co2-storage-in-aquifer-models-with-top-surface-mor-2
# https://pureportal.coventry.ac.uk/en/publications/unstable-preferential-fluid-displacement-effects-of-pore-scale-di
# https://pureportal.coventry.ac.uk/en/publications/a-novel-simulation-based-evolutionary-algorithm-to-optimize-build
# https://pureportal.coventry.ac.uk/en/publications/computational-analysis-of-methane-air-venturi-mixer-for-optimum-d
# https://pureportal.coventry.ac.uk/en/publications/design-and-cfd-simulation-of-an-innovative-intra-aortic-axial-pum
# https://pureportal.coventry.ac.uk/en/publications/internet-of-nano-things-for-dairy-farming
# https://pureportal.coventry.ac.uk/en/publications/lattice-reduction-aided-tabu-search-with-channel-dependent-stoppi
# https://pureportal.coventry.ac.uk/en/publications/precision-farming-sensor-analytics
# https://pureportal.coventry.ac.uk/en/publications/thermo-economic-analysis-of-a-hybrid-photovoltaicthermal-pvt-syst
# https://pureportal.coventry.ac.uk/en/publications/wettability-stabilizes-fluid-invasion-into-porous-media-via-nonlo
# https://pureportal.coventry.ac.uk/en/publications/cfd-investigation-of-mevlana-museum-air-velocity-distribution
# https://pureportal.coventry.ac.uk/en/publications/computational-analysis-of-airflow-distribution-inside-mevlana-mus
# https://pureportal.coventry.ac.uk/en/publications/impact-of-wettability-on-fluid-fluid-displacement
# https://pureportal.coventry.ac.uk/en/publications/net-oil-and-gas-well-test-system-9
# https://pureportal.coventry.ac.uk/en/publications/numerical-simulation-of-1-d-compression-stroke-using-smoothed-par
# https://pureportal.coventry.ac.uk/en/publications/pore-scale-study-of-drying-in-porous-media
# https://pureportal.coventry.ac.uk/en/publications/wireless-sensor-network-based-advisory-system-for-apple-scab-prev
# https://pureportal.coventry.ac.uk/en/publications/capillary-fracturing-in-granular-media-grc
# https://pureportal.coventry.ac.uk/en/publications/micromechanical-model-of-weakly-cemented-sediments
# https://pureportal.coventry.ac.uk/en/publications/minimal-seeds-for-shear-flow-turbulence-using-nonlinear-transient
# https://pureportal.coventry.ac.uk/en/publications/mechanisms-of-gas-transport-in-sediments-crossover-from-fingering
# https://pureportal.coventry.ac.uk/en/publications/pore-scale-modeling-of-overpressure-caused-by-hydrate-dissociatio
# https://pureportal.coventry.ac.uk/en/publications/thermodynamic-and-hydrodynamic-constraints-on-overpressure-caused
# https://pureportal.coventry.ac.uk/en/publications/crossover-from-fingering-to-fracturing-in-deformable-disordered-m
# https://pureportal.coventry.ac.uk/en/publications/crossover-from-fingering-to-fracturing-in-deformable-disordered-m-2
# https://pureportal.coventry.ac.uk/en/publications/frictional-granular-mechanics-a-variational-approach
# https://pureportal.coventry.ac.uk/en/publications/hydrate-growth-in-gas-rich-sediments-a-grain-scale-model
# https://pureportal.coventry.ac.uk/en/publications/using-nonlinear-transient-growth-to-construct-the-minimal-seed-fo
# https://pureportal.coventry.ac.uk/en/publications/highly-symmetric-travelling-waves-in-pipe-flow
# https://pureportal.coventry.ac.uk/en/publications/mechanical-properties-of-granular-materials-a-variational-approac
# https://pureportal.coventry.ac.uk/en/publications/micromechanics-of-hydrate-dissociation-in-marine-sediments-by-gra
# https://pureportal.coventry.ac.uk/en/publications/oil-and-gas-applications-for-digital-coriolis-mass-flow-metering-
# https://pureportal.coventry.ac.uk/en/publications/relative-periodic-orbits-in-transitional-pipe-flow
# https://pureportal.coventry.ac.uk/en/publications/asymmetric-helical-and-mirror-symmetric-traveling-waves-in-pipe-f
# https://pureportal.coventry.ac.uk/en/publications/internal-and-near-nozzle-flow-characteristics-in-an-enlarged-mode
# https://pureportal.coventry.ac.uk/en/publications/internal-and-near-nozzle-flow-of-a-pressure-swirl-atomizer-under-
# https://pureportal.coventry.ac.uk/en/publications/measurement-and-analysis-of-liquid-film-thickness-of-pressure-swi
# https://pureportal.coventry.ac.uk/en/publications/multi-phase-coriolis-flowmeter-6
# https://pureportal.coventry.ac.uk/en/publications/structure-and-mass-flux-distribution-of-a-side-opened-hollow-cone
# https://pureportal.coventry.ac.uk/en/publications/the-impact-of-acoustic-excitation-on-jet-mixing
# https://pureportal.coventry.ac.uk/en/publications/the-influence-of-airflow-on-fuel-spray-characteristics-from-a-sli-2
# https://pureportal.coventry.ac.uk/en/publications/automated-transmission-systems
# https://pureportal.coventry.ac.uk/en/publications/coriolis-coming-of-age
# https://pureportal.coventry.ac.uk/en/publications/the-effects-of-split-injection-and-egr-on-the-combustion-characte
# https://pureportal.coventry.ac.uk/en/publications/management-scenarios-for-the-jordan-river-salinity-crisis
# https://pureportal.coventry.ac.uk/en/publications/monitoring-waterflood-operations-halls-method-revisited
# https://pureportal.coventry.ac.uk/en/publications/quantifying-ground-water-inputs-along-the-lower-jordan-river
# https://pureportal.coventry.ac.uk/en/publications/self-consistent-mean-field-electrodynamics-in-two-and-three-dimen
# https://pureportal.coventry.ac.uk/en/publications/the-effects-of-injector-temperature-on-spray-and-combustion-chara
# https://pureportal.coventry.ac.uk/en/publications/the-need-for-standards-in-self-diagnosing-and-self-validating-ins
# https://pureportal.coventry.ac.uk/en/publications/the-relationships-between-groundwater-discharge-and-the-lower-jor
# https://pureportal.coventry.ac.uk/en/publications/waterflood-surveillance-and-control-incorporating-hall-plot-and-s
# https://pureportal.coventry.ac.uk/en/publications/atuador-de-engrenagens-com-um-ponto-de-apoio-para-as-barras-de-co
# https://pureportal.coventry.ac.uk/en/publications/automatic-transmission-system-with-transmission-brake
# https://pureportal.coventry.ac.uk/en/publications/how-a-coriolis-mass-flow-meter-can-operate-in-two-phase-gasliquid
# https://pureportal.coventry.ac.uk/en/publications/internal-flow-and-spray-characteristics-of-a-swirl-pressure-atomi
# https://pureportal.coventry.ac.uk/en/publications/rotary-drive
# https://pureportal.coventry.ac.uk/en/publications/rotary-drive-2
# https://pureportal.coventry.ac.uk/en/publications/shift-mechanism-having-a-rotating-drum
# https://pureportal.coventry.ac.uk/en/publications/three-dimensional-buoyant-convection-in-a-rectangular-cavity-with-3
# https://pureportal.coventry.ac.uk/en/publications/manual-transmission-in-particular-manual-transmission-for-a-motor
# https://pureportal.coventry.ac.uk/en/publications/pushing-coriolis-mass-flowmeters-to-the-limit
# https://pureportal.coventry.ac.uk/en/publications/spraywall-interaction-in-direct-injection-spark-ignition-engines-
# https://pureportal.coventry.ac.uk/en/publications/vehicle-air-braking-system
# https://pureportal.coventry.ac.uk/en/publications/sources-and-processes-of-nitrogen-along-the-lower-jordan-river
# https://pureportal.coventry.ac.uk/en/publications/vehicle-air-braking-system-2
# https://pureportal.coventry.ac.uk/en/publications/water-sources-and-quality-along-the-lower-jordan-river-regional-s
# https://pureportal.coventry.ac.uk/en/publications/condition-monitoring-and-validation-of-railway-point-machines
# https://pureportal.coventry.ac.uk/en/publications/on-line-compensation-in-a-digital-coriolis-mass-flow-meter
# https://pureportal.coventry.ac.uk/en/publications/plant-asset-management-via-intelligent-sensors-digital-distribute
# https://pureportal.coventry.ac.uk/en/publications/vehicle-air-braking-systems
# https://pureportal.coventry.ac.uk/en/publications/actuator-system-for-vehicular-automated-clutches-with-electric-mo
# https://pureportal.coventry.ac.uk/en/publications/shift-control-systemmethod-for-vehicle-equipped-with-driveline-re
# https://pureportal.coventry.ac.uk/en/publications/structure-of-sprays-generated-by-pressure-swirl-injectors-for-dir
# https://pureportal.coventry.ac.uk/en/publications/automated-clutch-control-and-calibration
# https://pureportal.coventry.ac.uk/en/publications/control-methodsystem-for-pneumatically-actuated-clutch
# https://pureportal.coventry.ac.uk/en/publications/selectable-enhanced-creep-control-mode-for-automated-clutch-and-v
# https://pureportal.coventry.ac.uk/en/publications/user-requirements-for-measurement-validation
# https://pureportal.coventry.ac.uk/en/publications/automatic-sensor-validation
# https://pureportal.coventry.ac.uk/en/publications/scrolling-gear-ratio-selection-control-system-and-method
# https://pureportal.coventry.ac.uk/en/publications/self-validation-improves-coriolis-flowmeter
# https://pureportal.coventry.ac.uk/en/publications/start-ratio-selection-control-system-and-method
# https://pureportal.coventry.ac.uk/en/publications/validating-data-from-smart-sensors

# %%
# Collect details from links

# %%
pd_data = []

for link_url in Publication_Link:
    response = requests.get(link_url)
    if response.status_code != 200:
        print(f"Failed to fetch {link_url}. Status code: {response.status_code}")
    else:
        tree = html.fromstring(response.content)
        xpaths = [
            '//p[@class="relations persons"]',
            '//div/h1/span',
            '//span[@class="date"][1]',
        ]

        details = []
        for xpath in xpaths:
            texts = tree.xpath(xpath)
            if texts:
                details.append(texts[0].text_content().strip())

        # Include the link in the details
        details.append(link_url)
        pd_data.append(details)

# %%
#Performs text normalization, tokenization, removal of common stop words, and stemming.

# %%
def clean_text(text):
    # Text normalization: Convert to lowercase
    text = text.lower()

    # Tokenization: Split text into words
    words = re.findall(r'\b\w+\b', text)

    # Remove common stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Stemming: Reduce words to their base form
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]

    return ' '.join(words)

# Create DataFrame with columns for Authors, Title, Publication Date, and Link
dataframe1 = pd.DataFrame(pd_data, columns=['Authors', 'Title', 'Published Date', 'Link'])

# Assuming you have a function clean_text defined somewhere
# Apply clean_text to each column in the DataFrame
for column in ['Authors', 'Title', 'Published Date']:
    dataframe1[column] = dataframe1[column].apply(clean_text)

# Create DataFrame with columns for Authors, Title, Publication Date, and Link
 
dataframe1.to_csv('Published_Data.csv', index=False)
print("Data saved successfully")

# Processing data
processing_data = dataframe1.copy()
# Out:
# Data saved successfully

# %%
#Creates an inverted index from the processed DataFrame.

# %%
def create_inverted_index(dataframe):
    inverted_index = defaultdict(list)

    for index, row in dataframe.iterrows():
        document_id = index  # Assuming each row in the DataFrame represents a document

        # Process and tokenize text data (adjust as needed based on your data)
        authors = row['Authors'].split() if 'Authors' in row else []
        title = row['Title'].split() if 'Title' in row else []
        publication_date = row['Published Date'].split() if 'Published Date' in row else []

        # Create a list of unique terms from the document
        document_terms = set(authors + title + publication_date)

        # Update the inverted index
        for term in document_terms:
            inverted_index[term].append(document_id)

    return inverted_index

# %%
# Build Inverted Index
inverted_index = create_inverted_index(processing_data)

# Example: Print the inverted index for the term 'spectral'
print("Inverted Index for 'spectral':", inverted_index.get('spectral', []))

# Sample processing for a single row
Sample = processing_data.loc[0, :].copy()
print("Sample Before:", Sample)

# Assuming you want to create a dictionary for indexing_trial
indexing_trial = {}

# Use the DataFrame index as the unique identifier
SerialNo = Sample.name
word = Sample.Title.split()[0]
example = {word: [SerialNo]}
indexing_trial.update(example)
print("Sample After:", Sample)
print("Indexing Trial:", indexing_trial)
# Out:
# Inverted Index for 'spectral': [0, 13, 58, 158]
# Sample Before: Authors                                evgeni gorbunov bogdan teaca
# Title                   allianc spectral solver kinet plasma turbul
# Published Date                                          12 oct 2023
# Link              https://pureportal.coventry.ac.uk/en/publicati...
# Name: 0, dtype: object
# Sample After: Authors                                evgeni gorbunov bogdan teaca
# Title                   allianc spectral solver kinet plasma turbul
# Published Date                                          12 oct 2023
# Link              https://pureportal.coventry.ac.uk/en/publicati...
# Name: 0, dtype: object
# Indexing Trial: {'allianc': [0]}

# %%
#Opens the link associated with a selected item in the Treeview (double-click event).
def open_link(event):
    item = tree.selection()[0]
    link = tree.item(item, 'values')[-1]
    if link:
        webbrowser.open(link)

#Loads data from a CSV file (Published_Data.csv).
def search_data(query):
    # Load the data
    dataframe = pd.read_csv("Published_Data.csv")

    # Filter the data based on the search query
    result_df = dataframe[
        dataframe.apply(lambda row: query.lower() in " ".join(row).lower(), axis=1)
    ]

    return result_df

#Clears previous search results in the Treeview.
def display_search_results(results):
    # Clear the previous search results
    for item in tree.get_children():
        tree.delete(item)

    # Insert new search results
    for index, row in results.iterrows():
        values = row.tolist()
        
        # Check if the row already exists in the Treeview
        existing_items = tree.get_children()
        is_duplicate = any(tree.item(item, 'values') == values for item in existing_items)
        
        if not is_duplicate:
            tree.insert("", "end", values=values)

#Retrieves the search query from the entry field and performs a search.
def search_button_clicked():
    query = entry.get()
    results = search_data(query)
    display_search_results(results)

# %%
#GUI Creation

# %%
# Create the main window
root = tk.Tk()
root.title("Publication Search Engine for Research Centre for Fluid and Complex Systems")
root.geometry("1000x800")

# Configure background color
root.configure(bg='#ADD8E6') # Light Blue color

# Create the search bar
label = tk.Label(root, text="Search:", font=("Helvetica", 16, "bold"), bg='#f0f0f0')
label.pack(side=tk.TOP, padx=10, pady=10)

entry = tk.Entry(root, width=40, font=("Helvetica", 14))
entry.pack(side=tk.TOP, padx=10, pady=5)

# Style the search button
style = ttk.Style()
style.configure("TButton", padding=6, relief="flat", background="#4299ff", foreground="black")
search_button = ttk.Button(root, text="Search", style="TButton", command=search_button_clicked)
search_button.pack(side=tk.TOP, padx=10, pady=5)

# %%
# Create the result table
frame = ttk.Frame(root)
frame.pack(padx=10, pady=10, side=tk.TOP, fill="both", expand=True)

tree = ttk.Treeview(
    frame,
    columns=("Authors", "Title", "Published Date", "Link"),
    show="headings",
    selectmode="browse",
)

# Configure header colors
style.configure("Treeview.Heading", background="#4299ff", foreground="black")

tree.column("Authors", width=200, anchor=tk.CENTER)
tree.column("Title", width=300, anchor=tk.W)
tree.column("Published Date", width=150, anchor=tk.CENTER)
tree.column("Link", width=200, anchor=tk.CENTER)

tree.heading("Authors", text="Authors")
tree.heading("Title", text="Title")
tree.heading("Published Date", text="Published Date")
tree.heading("Link", text="Link")

tree["height"] = 15

# Configure row colors
style.configure("Treeview", background="#f0f0f0", foreground="black")

vertical_scrollbar = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
tree.configure(yscrollcommand=vertical_scrollbar.set)
vertical_scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
tree.pack(side=tk.LEFT, expand=True, fill="both")

# Clear the previous search results
for item in tree.get_children():
    tree.delete(item)

# Bind double-click event to open link
tree.bind("<Double-1>", open_link)

# Run the GUI
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 43
#      40 tree.bind("<Double-1>", open_link)
#      42 # Run the GUI
# ---> 43 root.mainloop()
#
# File ~/anaconda3/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:
